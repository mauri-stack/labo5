# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
import os
from scipy.signal import find_peaks

# %% [markdown]
# # Ajuste de histograma
#
# Probamos con una de nuestras mediciones del régimen Poissoniano
